# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import numpy as np
# import gmaps
import os
import matplotlib.pyplot as plt
import json
import time

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  dhidhdhoo   6.8833   73.1000     27.95        79         100
# 1        1  grytviken -54.2811  -36.5092     -2.43        80          42
# 2        2  taoudenni  22.6783   -3.9836     37.08        21          76
# 3        3   waitangi -43.9535 -176.5597     13.79        83          50
# 4        4  hiratacho  35.4333  132.8167     26.01       100          75
#
#    Wind Speed Country        Date
# 0        6.37      MV  1689724123
# 1        3.11      GS  1689724123
# 2        4.93      ML  1689724123
# 3        1.34      NZ  1689724123
# 4        2.57      JP  1689724123

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)
# YOUR CODE HERE


# Display the map
map_plot
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
narrowed_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 36) & (city_data_df["Max Temp"] > 21) \
    & (city_data_df["Wind Speed"] < 4.5) \
    & (city_data_df["Cloudiness"] == 0)
]


# Drop any rows with null values
# YOUR CODE HERE
narrowed_df = narrowed_df.dropna()

# Display sample data
# YOUR CODE HERE
narrowed_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 32        32     al qaryatayn  34.2296   37.2407     23.92        31
# 42        42         misratah  32.3754   15.0925     27.76        74
# 100      100         harmanli  41.9333   25.9000     24.91        49
# 128      128            benxi  41.2886  123.7650     25.18        50
# 131      131        morondava -20.2833   44.2833     21.69        59
# 142      142      al bardiyah  31.7561   25.0865     26.12        65
# 150      150       siwa oasis  29.2041   25.5195     29.85        29
# 158      158       fort bragg  35.1390  -79.0060     32.08        59
# 183      183      bani suwayf  29.0744   31.0979     29.14        40
# 184      184            aswan  24.0934   32.9070     33.61        14
# 199      199     antonio enes -16.2325   39.9086     21.30        79
# 222      222        jamestown  42.0970  -79.2353     22.80        46
# 254      254  remire-montjoly   4.9167  -52.2667     26.02        83
# 301      301        astrakhan  46.3497   48.0408     21.93        53
# 310      310        pyongyang  39.0339  125.7543     25.64        76
# 318      318    fort mcmurray  56.7268 -111.3810     24.77        43
# 347      347             arar  30.9753   41.0381     32.01         8
# 352      352           atmore  31.0238  -87.4939     31.39        55
# 353      353           tobruk  32.0836   23.9764     26.14        75
# 395      395           illizi  26.4833    8.4667     30.89        19
# 406      406            yatou  37.1500  122.3833     26.95        58
# 420      420      san lawrenz  36.0553   14.2040     27.67        65
# 433      433          kearney  40.6995  -99.0815     27.95        78
# 495      495           laurel  39.0993  -76.8483     30.94        60
# 507      507           zarzis  33.5040   11.1122     28.91        66
# 516      516      tamanrasset  22.7850    5.5228     28.95        12
# 522      522         yelizovo  53.1873  158.3805     21.08        64
# 528      528             ghat  24.9647   10.1728     29.60        20
# 550      550         ialoveni  46.9431   28.7778     24.16        63
# 565      565           winona  43.9666  -91.7668     25.89        41
# 594      594          al jawf  29.5000   38.7500     27.86        18
#
#      Cloudiness  Wind Speed Country        Date
# 32            0        1.66      SY  1689724126
# 42            0        3.35      LY  1689724127
# 100           0        0.78      BG  1689724133
# 128           0        1.64      CN  1689724138
# 131           0        2.93      MG  1689724138
# 142           0        3.33      LY  1689724139
# 150           0        3.05      EG  1689724140
# 158           0        3.60      US  1689724141
# 183           0        4.23      EG  1689724144
# 184           0        3.60      EG  1689724145
# 199           0        3.14      MZ  1689724146
# 222           0        3.60      US  1689723854
# 254           0        1.54      GF  1689724102
# 301           0        3.00      RU  1689724158
# 310           0        1.39      KP  1689724159
# 318           0        1.03      CA  1689723870
# 347           0        3.60      SA  1689724164
# 352           0        2.37      US  1689724165
# 353           0        4.18      LY  1689724165
# 395           0        4.04      DZ  1689724170
# 406           0        0.59      CN  1689724171
# 420           0        3.01      MT  1689724173
# 433           0        4.12      US  1689724050
# 495           0        3.09      US  1689723922
# 507           0        3.27      TN  1689724183
# 516           0        2.06      DZ  1689724183
# 522           0        2.00      RU  1689724184
# 528           0        3.38      LY  1689724185
# 550           0        2.57      MD  1689724189
# 565           0        0.00      US  1689724190
# 594           0        4.43      SA  1689724194

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = narrowed_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 32      al qaryatayn      SY  34.2296   37.2407        31
# 42          misratah      LY  32.3754   15.0925        74
# 100         harmanli      BG  41.9333   25.9000        49
# 128            benxi      CN  41.2886  123.7650        50
# 131        morondava      MG -20.2833   44.2833        59
# 142      al bardiyah      LY  31.7561   25.0865        65
# 150       siwa oasis      EG  29.2041   25.5195        29
# 158       fort bragg      US  35.1390  -79.0060        59
# 183      bani suwayf      EG  29.0744   31.0979        40
# 184            aswan      EG  24.0934   32.9070        14
# 199     antonio enes      MZ -16.2325   39.9086        79
# 222        jamestown      US  42.0970  -79.2353        46
# 254  remire-montjoly      GF   4.9167  -52.2667        83
# 301        astrakhan      RU  46.3497   48.0408        53
# 310        pyongyang      KP  39.0339  125.7543        76
# 318    fort mcmurray      CA  56.7268 -111.3810        43
# 347             arar      SA  30.9753   41.0381         8
# 352           atmore      US  31.0238  -87.4939        55
# 353           tobruk      LY  32.0836   23.9764        75
# 395           illizi      DZ  26.4833    8.4667        19
# 406            yatou      CN  37.1500  122.3833        58
# 420      san lawrenz      MT  36.0553   14.2040        65
# 433          kearney      US  40.6995  -99.0815        78
# 495           laurel      US  39.0993  -76.8483        60
# 507           zarzis      TN  33.5040   11.1122        66
# 516      tamanrasset      DZ  22.7850    5.5228        12
# 522         yelizovo      RU  53.1873  158.3805        64
# 528             ghat      LY  24.9647   10.1728        20
# 550         ialoveni      MD  46.9431   28.7778        63
# 565           winona      US  43.9666  -91.7668        41
# 594          al jawf      SA  29.5000   38.7500        18

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 # YOUR CODE HERE
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}
    # YOUR CODE HERE


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row["Lat"]
    longitude = row["Lng"]    
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    params["bias"] = f"proximity:{longitude},{latitude}"
        
        # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


        # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
        
    # Convert the API response to JSON format
    name_address = name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# al qaryatayn - nearest hotel: No hotel found
# misratah - nearest hotel: الفندق السياحى
# harmanli - nearest hotel: Авангард
# benxi - nearest hotel: 富佳大酒店
# morondava - nearest hotel: Hotel Sharon Menabe
# al bardiyah - nearest hotel: فندق البردي
# siwa oasis - nearest hotel: فندق الكيلانى
# fort bragg - nearest hotel: Airborne Inn Lodging
# bani suwayf - nearest hotel: قاعة المؤتمرات
# aswan - nearest hotel: Yaseen hotel
# antonio enes - nearest hotel: Hotel Quirimbas
# jamestown - nearest hotel: DoubleTree Jamestown
# remire-montjoly - nearest hotel: Complexe Belova
# astrakhan - nearest hotel: Omega
# pyongyang - nearest hotel: Ponghwansan Hotel
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# arar - nearest hotel: دار أوتيل Dar Otel
# atmore - nearest hotel: Fairfield Inn & Suites
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# illizi - nearest hotel: بوناقة
# yatou - nearest hotel: No hotel found
# san lawrenz - nearest hotel: Ta Majsi
# kearney - nearest hotel: Days Inn
# laurel - nearest hotel: Quality Inn & Suites
# zarzis - nearest hotel: Zephir Hotel & Spa
# tamanrasset - nearest hotel: فندق الأمان
# yelizovo - nearest hotel: Николина Усадьба
# ghat - nearest hotel: فندق تاسيلي
# ialoveni - nearest hotel: Grace Vila
# winona - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
#                 City Country      Lat       Lng  Humidity  \
# 32      al qaryatayn      SY  34.2296   37.2407        31
# 42          misratah      LY  32.3754   15.0925        74
# 100         harmanli      BG  41.9333   25.9000        49
# 128            benxi      CN  41.2886  123.7650        50
# 131        morondava      MG -20.2833   44.2833        59
# 142      al bardiyah      LY  31.7561   25.0865        65
# 150       siwa oasis      EG  29.2041   25.5195        29
# 158       fort bragg      US  35.1390  -79.0060        59
# 183      bani suwayf      EG  29.0744   31.0979        40
# 184            aswan      EG  24.0934   32.9070        14
# 199     antonio enes      MZ -16.2325   39.9086        79
# 222        jamestown      US  42.0970  -79.2353        46
# 254  remire-montjoly      GF   4.9167  -52.2667        83
# 301        astrakhan      RU  46.3497   48.0408        53
# 310        pyongyang      KP  39.0339  125.7543        76
# 318    fort mcmurray      CA  56.7268 -111.3810        43
# 347             arar      SA  30.9753   41.0381         8
# 352           atmore      US  31.0238  -87.4939        55
# 353           tobruk      LY  32.0836   23.9764        75
# 395           illizi      DZ  26.4833    8.4667        19
# 406            yatou      CN  37.1500  122.3833        58
# 420      san lawrenz      MT  36.0553   14.2040        65
# 433          kearney      US  40.6995  -99.0815        78
# 495           laurel      US  39.0993  -76.8483        60
# 507           zarzis      TN  33.5040   11.1122        66
# 516      tamanrasset      DZ  22.7850    5.5228        12
# 522         yelizovo      RU  53.1873  158.3805        64
# 528             ghat      LY  24.9647   10.1728        20
# 550         ialoveni      MD  46.9431   28.7778        63
# 565           winona      US  43.9666  -91.7668        41
# 594          al jawf      SA  29.5000   38.7500        18
#
#                   Hotel Name
# 32            No hotel found
# 42            الفندق السياحى
# 100                 Авангард
# 128                    富佳大酒店
# 131      Hotel Sharon Menabe
# 142              فندق البردي
# 150            فندق الكيلانى
# 158     Airborne Inn Lodging
# 183           قاعة المؤتمرات
# 184             Yaseen hotel
# 199          Hotel Quirimbas
# 222     DoubleTree Jamestown
# 254          Complexe Belova
# 301                    Omega
# 310        Ponghwansan Hotel
# 318   Nomad Hotel and Suites
# 347       دار أوتيل Dar Otel
# 352   Fairfield Inn & Suites
# 353  فندق زهرة البطنان -طبرق
# 395                   بوناقة
# 406           No hotel found
# 420                 Ta Majsi
# 433                 Days Inn
# 495     Quality Inn & Suites
# 507       Zephir Hotel & Spa
# 516              فندق الأمان
# 522         Николина Усадьба
# 528              فندق تاسيلي
# 550               Grace Vila
# 565           No hotel found
# 594           No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
